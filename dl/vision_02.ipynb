# %%
import tensorflow as tf

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.95):
      print("\n 95% de précision atteint, nous pouvons arrêter l'entrainement !")
      self.model.stop_training = True

callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images = training_images / 255.0
test_images = test_images / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=50, callbacks=[callbacks])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4987 - accuracy: 0.8252
# Epoch 2/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3747 - accuracy: 0.8644
# Epoch 3/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3376 - accuracy: 0.8767
# Epoch 4/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3146 - accuracy: 0.8836
# Epoch 5/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2962 - accuracy: 0.8898
# Epoch 6/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2810 - accuracy: 0.8958
# Epoch 7/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2702 - accuracy: 0.8988
# Epoch 8/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2589 - accuracy: 0.9030
# Epoch 9/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2494 - accuracy: 0.9066
# Epoch 10/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2407 - accuracy: 0.9107
# Epoch 11/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2311 - accuracy: 0.9133
# Epoch 12/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2252 - accuracy: 0.9146
# Epoch 13/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2159 - accuracy: 0.9184
# Epoch 14/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2120 - accuracy: 0.9199
# Epoch 15/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2048 - accuracy: 0.9224
# Epoch 16/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1990 - accuracy: 0.9251
# Epoch 17/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1944 - accuracy: 0.9273
# Epoch 18/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1886 - accuracy: 0.9283
# Epoch 19/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1832 - accuracy: 0.9312
# Epoch 20/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1791 - accuracy: 0.9315
# Epoch 21/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1748 - accuracy: 0.9333
# Epoch 22/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1703 - accuracy: 0.9359
# Epoch 23/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1675 - accuracy: 0.9365
# Epoch 24/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1615 - accuracy: 0.9394
# Epoch 25/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1578 - accuracy: 0.9394
# Epoch 26/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1560 - accuracy: 0.9403
# Epoch 27/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1516 - accuracy: 0.9430
# Epoch 28/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1488 - accuracy: 0.9441
# Epoch 29/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1443 - accuracy: 0.9460
# Epoch 30/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1411 - accuracy: 0.9466
# Epoch 31/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1383 - accuracy: 0.9480
# Epoch 32/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1371 - accuracy: 0.9486
# Epoch 33/50
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9510\95% de précision atteint, nous pouvons arrêter l'entrainement !
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1332 - accuracy: 0.9510
